# %% [markdown]
# <a href="https://colab.research.google.com/github/olorunfemibabalola/Computer-Vision-Learning/blob/main/Assignment_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# Dataset Downloading

# %%
# !mkdir - p /root/.config/kaggle
# !chmod 600 /root/.config/kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘-’: File exists
# mkdir: cannot create directory ‘p’: File exists
# mkdir: cannot create directory ‘/root/.config/kaggle’: File exists
# chmod: cannot access '/root/.config/kaggle/kaggle.json': No such file or directory

# %%
import kaggle
# !kaggle competitions download -c bucv26 --force
# !unzip -o *.zip
# Out:
# You must authenticate before you can call the Kaggle API.
# Follow the instructions to authenticate at: https://github.com/Kaggle/kaggle-cli/blob/main/docs/README.md#authentication
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3264/1244224261.py in <cell line: 0>()
# ----> 1 import kaggle
#       2 get_ipython().system('kaggle competitions download -c bucv26 --force')
#       3 get_ipython().system('unzip -o *.zip')
#
# /usr/local/lib/python3.12/dist-packages/kaggle/__init__.py in <module>
#       8 enable_oauth = os.environ.get("KAGGLE_ENABLE_OAUTH") in ("1", "true", "yes")
#       9 api = KaggleApi(enable_oauth=enable_oauth)
# ---> 10 api.authenticate()
#
# /usr/local/lib/python3.12/dist-packages/kaggle/api/kaggle_api_extended.py in authenticate(self)
# ...

# %%
class xrayDataset(Dataset):
  def _init_(self, img_dir, df_labels, transform):
    self.img_dir = img_dir
    self.df_labels= df_labels
    self.transform = transform
    self.img_files = os.listdir(img_dir)
    if self.df_labels is not None:
      self.file2label = dict(zip(self.df_labels['file_name'], zip(self.df_labels['sex'], self.df_labels['bmi'])))
  def _len_(self):
    return len(self.img_files)
  def _getitem_(self, idx):
    img_name = self.img_files[idx]
    image = Image.open(f'{self.img_dir}/{img_name}').covert('L')
    if self.transform:
      image = self.transform(image)
    if self.df_labels is not None:
      label = self.df_labels
    label = self.file2label[img_name]
    return image, sex, bmi
